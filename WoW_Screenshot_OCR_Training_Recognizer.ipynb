# %% [markdown]
# <a href="https://colab.research.google.com/github/geo-tp/Keras-Colaboratory-Models/blob/main/WoW_Screenshot_OCR_Training_Recognizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # WoW Screenshot OCR model - TRAINING RECOGNIZER
#
# We will fine tune recognizer to be able to read texts in WoW Screenshots
#
#   - MODELS
# - Text Detector with CRAFT weights, it should locate and crop texts
# - Text Recognizer with Kurapan weights, it should read texts
#
#   - ASSETS
# - WoW fonts : FRIZQT, SKURRI, ARIALN, MORPHEUS
# - BG images : Simple WoW images with no UI and text rendered
#
#   - TRAINING
# - We will create screenshot generator with text
# - We will create text frame generator to fit Recognizer
# - We will fine tune recognizer to be able to read WoW game fonts
#
#   - IMAGE_OCR
# - A updated package of keras_ocr to work with new colab backend https://github.com/geo-tp/image-ocr

# %% [markdown]
# ## Install

# %%
# !pip install image-ocr

# %% [markdown]
# ## Import

# %%
import zipfile
import datetime
import string
import math
import os
import sys
import tqdm
import matplotlib.pyplot as plt
import tensorflow as tf
import sklearn.model_selection
from keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
import numpy

import image_ocr as keras_ocr

# %% [markdown]
# ## Fonts & BGs - Assets needed to be able to generate WoW screenshot with fonts
#
# - Use Drive or import WoW Fonts .TTF in Colab
# - Use Drive or import WoW ingame image .jpg with no text and no UI displayed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
default_dir = sys.path[0] + "/drive/MyDrive/"
fonts_dir = default_dir + "wowfonts/"
bgs_dir = default_dir + "wowbackgrounds/"

fonts = os.listdir(fonts_dir) * 16 # artificial increase set size
fonts = [fonts_dir + font for font in fonts]

backgrounds = os.listdir(bgs_dir) * 16 # artificial increase set size
backgrounds = [bgs_dir +  bg for bg in backgrounds]

# %% [markdown]
#  ## Detector Image Generator - Generate a "screenshot" with random text

# %%
alphabet = string.digits + string.ascii_letters
recognizer_alphabet = ''.join(sorted(set(alphabet.lower())))

text_generator = keras_ocr.data_generation.get_text_generator(alphabet=alphabet)
print('The first generated text is:', next(text_generator))

def get_train_val_test_split(arr):
    train, valtest = sklearn.model_selection.train_test_split(arr, train_size=0.8, random_state=42)
    val, test = sklearn.model_selection.train_test_split(valtest, train_size=0.5, random_state=42)
    return train, val, test

background_splits = get_train_val_test_split(backgrounds)
font_splits = get_train_val_test_split(fonts)

image_generators = [
    keras_ocr.data_generation.get_image_generator(
        height=640,
        width=640,
        text_generator=text_generator,
        font_groups={
            alphabet: current_fonts,
        },
        backgrounds=current_backgrounds,
        font_size=(60, 120),
        margin=50,
    )  for current_fonts, current_backgrounds in zip(
        font_splits,
        background_splits
    )
]

# See random generated screenshot
image, lines = next(image_generators[1])
text = keras_ocr.data_generation.convert_lines_to_paragraph(lines)
print('The first generated validation image (below) contains:', text)
plt.imshow(image)
# Out:
# The first generated text is: ForreignandprecisedetailedandtechnicalDuringitsrebuilding
# The first generated validation image (below) contains: Administrationput
# rulingsNeverthele
# sstheSupreme

# %% [markdown]
# ## Models Defintion - Recognizer and Detector

# %%
# Pre trained default weights for both models
recognizer = keras_ocr.recognition.Recognizer()
detector = keras_ocr.detection.Detector(weights='clovaai_general')
recognizer = keras_ocr.recognition.Recognizer(
    alphabet=recognizer_alphabet,
    weights='kurapan'
)

# Freeze backbone layers
for layer in recognizer.backbone.layers:
    layer.trainable = False

recognizer.compile()
# Out:
# Looking for /root/.keras-ocr/crnn_kurapan.h5
# Looking for /root/.keras-ocr/craft_mlt_25k.h5
# Looking for /root/.keras-ocr/crnn_kurapan.h5

# %% [markdown]
# ## Recognizer Text Frame Generator - Generate a text with WoW font and BG

# %%
max_length = 10
recognition_image_generators = [
    keras_ocr.data_generation.convert_image_generator_to_recognizer_input(
        image_generator=image_generator,
        max_string_length=min(recognizer.training_model.input_shape[1][1], max_length),
        target_width=recognizer.model.input_shape[2],
        target_height=recognizer.model.input_shape[1],
        margin=1
    ) for image_generator in image_generators
]

# See random generated text frames
image, text = next(recognition_image_generators[0])
print('This image contains:', text)
plt.imshow(image)
# Out:
# This image contains: Aprotectiv

# %%
# See random generated text frames
image, text = next(recognition_image_generators[0])
print('This image contains:', text)
plt.imshow(image)
# Out:
# This image contains: aciertheso

# %% [markdown]
# ## Recognizer Train Generator - Create training , validation and test datasets

# %%
recognition_batch_size = 8
data_dir = '.'

recognizer_basepath = os.path.join(data_dir, f'recognizer_{datetime.datetime.now().isoformat()}')

recognition_train_generator, recognition_val_generator, recognition_test_generator = [
    recognizer.get_batch_generator(
    image_generator=image_generator,
    batch_size=recognition_batch_size,
    lowercase=True
    ) for image_generator in recognition_image_generators
]

# %% [markdown]
# ## Callbacks - Save best model and early stop

# %%
# Stop iterations regarding to loss value
early_stop = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=20)

# Saving model at each epoch if values are better than the previous
model_checkpoint = ModelCheckpoint(default_dir+'wow_ocr.h5', monitor='loss', mode='min', save_best_only=False, verbose=1, save_weights_only=True)

# %% [markdown]
# ## Resume Training - Load recognizer saved weights if any

# %%
weights_path = default_dir+"wow_ocr.h5"

if os.path.exists(weights_path):
   recognizer.model.load_weights(weights_path)

# %% [markdown]
# ## Recognizer Training - Fit

# %%
recognizer.training_model.fit(
    recognition_train_generator,
    steps_per_epoch=math.ceil(len(background_splits[0]) / recognition_batch_size),
    validation_data=recognition_val_generator,
    validation_steps=math.ceil(len(background_splits[1]) / recognition_batch_size),
    epochs=1000,
    callbacks=[model_checkpoint, early_stop],
)

# %% [markdown]
# # WoW Screenshot OCR Model - PARSING SCREENSHOT TO TEXT

# %% [markdown]
# ## Create Pipeline with fine tuned recognizer

# %%
if os.path.exists(weights_path):
   recognizer.model.load_weights(weights_path)

pipeline = keras_ocr.pipeline.Pipeline(recognizer=recognizer)
# Out:
# Looking for /root/.keras-ocr/craft_mlt_25k.h5

# %% [markdown]
# ## Get Predictions with original screenshots

# %%
# Screenshots example
images = [
    keras_ocr.tools.read(url)
    for url in [
        "https://archive.thealphaproject.eu/media/Alpha-Project-Archive/UNSORTED/from_alpha_archive_03012023/thumb_rd_leafpile.jpg",
        "https://archive.thealphaproject.eu/media/Alpha-Project-Archive/Images/Azeroth/Cities/Stormwind/DDD32.jpg",
        "https://archive.thealphaproject.eu/media/Alpha-Project-Archive/UNSORTED/zigg.org/15/WoWScrnShot_100104_180533.jpg",
        "https://archive.thealphaproject.eu/media/Alpha-Project-Archive/Images/Azeroth/Cities/Stormwind/2003-06-30-10-31-12.jpg",
        "https://archive.thealphaproject.eu/media/Alpha-Project-Archive/Images/Azeroth/Cities/Stormwind/GGG22.jpg",
    ]
]

# Results
prediction_groups = pipeline.recognize(images)
# Each list of predictions in prediction_groups is a list of
# (word, box) tuples.
# Out:
# 1/1 [==============================] - 1s 625ms/step
# 5/5 [==============================] - 0s 15ms/step

# %% [markdown]
# ## Plot Results

# %%
fig, axs = plt.subplots(nrows=len(images), figsize=(20, 20))
for ax, image, predictions in zip(axs, images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=image, predictions=predictions, ax=ax)
